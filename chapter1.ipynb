# %%
from PIL import Image

# %%
pil_im = Image.open('./gaoyuanyuan.jpeg')
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x883>

# %%
pil_im.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=580x883>

# %%
import os

# %%
pil_im.thumbnail((720,720))

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=473x720>

# %%
box = (100,100,400,400)
region = pil_im.crop(box)

# %%
region
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
region = region.transpose(Image.ROTATE_180)
pil_im.paste(region,box)

# %%
region
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=473x720>

# %%
out =   pil_im.resize((128, 128))

# %%
out
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
out = pil_im.rotate(45)

# %%
out
# Out:
# <PIL.Image.Image image mode=RGB size=473x720>

# %%
from pylab import *

# %%
im = array(Image.open("./gaoyuanyuan.jpeg"))

# %%
imshow(im)

# %%
x = [100, 100, 400, 400]
y = [200, 500, 200, 500]

# %%
plot(x, y, 'r*')

# %%
show()

# %%
plot(x[:2],y[:2])

# %%
plot(x,y,'ks:')

# %%
im = array(Image.open("./gaoyuanyuan.jpeg").convert('L'))

figure()
gray()
contour(im, origin="image")
axis("equal")
axis("off")
# Out:
# (0.5, 579.5, 0.5, 882.5)

# %%
figure()
hist(im.flatten(),128)
show()
